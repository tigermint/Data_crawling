# %%
import httplib2
import os
import sys

from apiclient.discovery import build
from apiclient.errors import HttpError
from oauth2client.tools import argparser


DEVELOPER_KEY = "AIzaSyB32F1sdJPVljEVN_0jYpqKzgvSPfjmHKQ"
YOUTUBE_API_SERVICE_NAME = "youtube"
YOUTUBE_API_VERSION = "v3"

# %%
# youtube api 가져오기
youtube = build(YOUTUBE_API_SERVICE_NAME, YOUTUBE_API_VERSION, developerKey = DEVELOPER_KEY)
# api는 만들어놓은 back-end이다 -> 사용시 request에 따른 매개변수들을 사용해주어야 한다. 
# youtube data api에서 필요한 매개변수들을 사용하기
search_response = youtube.search().list(
    q = "슈카월드",
    order = "relevance",
    part = "snippet",
    maxResults = 50
).execute() # 실행하다

# %%
search_response
# Out:
# {'kind': 'youtube#searchListResponse',
#  'etag': 'B9tXLnjJfONDQCHO3HQM6rHQWOo',
#  'nextPageToken': 'CDIQAA',
#  'regionCode': 'KR',
#  'pageInfo': {'totalResults': 104890, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#searchResult',
#    'etag': 'gFHiTq8-UAm22YeOOz9bK74GL_M',
#    'id': {'kind': 'youtube#video', 'videoId': 'f84hATMEdWk'},
#    'snippet': {'publishedAt': '2021-08-30T11:05:08Z',
#     'channelId': 'UCsJ6RuBiTVWRX156FVbeaGg',
#     'title': 'NC소프트 충격적인 주식 손실, 분노의 주주들',
#     'description': '0:00 ~ 1:27 선사과문 1:27 ~ 25:43 엔씨소프트 충격의 하락과 엄청난 손실 25:43 ~ 31:37 주주의 입장에서 어렵고 딱딱한 경제,시사,금융 이야기를 쉽고 유쾌하게 ...',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/f84hATMEdWk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/f84hATMEdWk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/f84hATMEdWk/hqdefault.jpg',
#       'width': 480,
# ...

# %%
channel_id = search_response["items"][0]["snippet"]["channelId"]
channel_id # 원하는거 추출하면 된다
# Out:
# 'UCsJ6RuBiTVWRX156FVbeaGg'

# %%
playlists = youtube.playlists().list(
    channelId = channel_id, # 위에 뽑아놓은 channelId로 들어간다
    part = "snippet",
    maxResults = 20, 
).execute()

# %%
playlists
# Out:
# {'kind': 'youtube#playlistListResponse',
#  'etag': 'BtDFhl1Lg8ePVeDe3yTCA8Su-8A',
#  'pageInfo': {'totalResults': 16, 'resultsPerPage': 20},
#  'items': [{'kind': 'youtube#playlist',
#    'etag': 'ustQEOg9RNwjUaaeJ-8wrL9Ude0',
#    'id': 'PLJPjg3It2DXSmRlcwlsP3sf2RDt1EX4Dp',
#    'snippet': {'publishedAt': '2020-09-10T10:28:17Z',
#     'channelId': 'UCsJ6RuBiTVWRX156FVbeaGg',
#     'title': '꿀잼 세계사',
#     'description': '',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/f4ZvLaaBZ1k/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/f4ZvLaaBZ1k/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/f4ZvLaaBZ1k/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/f4ZvLaaBZ1k/sddefault.jpg',
#       'width': 640,
#       'height': 480},
# ...

# %%
# pandas로 엑셀파일 형식으로 정리하기
import pandas as pd

playlist_titles = []
playlist_ids = []

# %%
for i in playlists["items"]:
    playlist_titles.append(i["snippet"]["title"])    
    playlist_ids.append(i["id"])

# %%
playlist_titles
# Out:
# ['꿀잼 세계사',
#  'Trading Idea를 찾아서',
#  "슈카's 추천영상",
#  '방구석 전문가의 이불밖 탐험',
#  '이슈&뉴스',
#  '레전(前)썰',
#  '슈카의 일상썰',
#  '슈카의 시사상식썰',
#  '[게임] 게임방송 모음 (카오스, slay the spiree 등)',
#  '슈카월드 경제 썰방송 모음',
#  '슈카의 아재토크 풀버전',
#  '[꿀잼 하이라이트 모음] 식빵과 슈카의 아재토크',
#  '식빵과 슈카의 아재토크 풀버전 (31~40회)',
#  '식빵과 슈카의 아재토크 풀버전 (21~30회)',
#  '식빵과 슈카의 아재토크 풀버전 (11~20회)',
#  '식빵과 슈카의 아재토크 풀버전 (1~10회)']

# %%
playlist_ids
# Out:
# ['PLJPjg3It2DXSmRlcwlsP3sf2RDt1EX4Dp',
#  'PLJPjg3It2DXTjyMDpv3529npTRIfynn_P',
#  'PLJPjg3It2DXQ2lPgdpD7bcKo-baK4lUpW',
#  'PLJPjg3It2DXRaWcHvoZ-rqUsLcXPlH77O',
#  'PLJPjg3It2DXSAD6OzQ7QON6li-QcbBFOl',
#  'PLJPjg3It2DXQxAtY-8bViwEe9aSRCHfds',
#  'PLJPjg3It2DXTKV8xwYQoQsRM3IlwQN4Kp',
#  'PLJPjg3It2DXQUdlAocHh5FASozqwtJavv',
#  'PLJPjg3It2DXTn7wUE7Wx9W9krpQ739TyK',
#  'PLJPjg3It2DXQWxhAz-EFgwk1HqD9QjEhp',
#  'PLJPjg3It2DXQ62wofZIzsf8Y12OEuopxI',
#  'PLJPjg3It2DXQkopJchhi7M-hxZG3M02BR',
#  'PLJPjg3It2DXT_0ni26IrX3j4bK0UEjkTV',
#  'PLJPjg3It2DXTRjsdKC1V-skruOqXD6oDl',
#  'PLJPjg3It2DXRIZVHedyWi92ihQ39MqlIx',
#  'PLJPjg3It2DXSb4U5GTaTHzijll2rp3WdQ']

# %%
playlist_df = pd.DataFrame([playlist_titles, playlist_ids]).T
playlist_df.columns = ["playlist", "playlist_id"]

# %%
playlist_df
# Out:
#                                  playlist                         playlist_id
# 0                                  꿀잼 세계사  PLJPjg3It2DXSmRlcwlsP3sf2RDt1EX4Dp
# 1                       Trading Idea를 찾아서  PLJPjg3It2DXTjyMDpv3529npTRIfynn_P
# 2                               슈카's 추천영상  PLJPjg3It2DXQ2lPgdpD7bcKo-baK4lUpW
# 3                         방구석 전문가의 이불밖 탐험  PLJPjg3It2DXRaWcHvoZ-rqUsLcXPlH77O
# 4                                   이슈&뉴스  PLJPjg3It2DXSAD6OzQ7QON6li-QcbBFOl
# 5                                  레전(前)썰  PLJPjg3It2DXQxAtY-8bViwEe9aSRCHfds
# 6                                 슈카의 일상썰  PLJPjg3It2DXTKV8xwYQoQsRM3IlwQN4Kp
# 7                               슈카의 시사상식썰  PLJPjg3It2DXQUdlAocHh5FASozqwtJavv
# 8   [게임] 게임방송 모음 (카오스, slay the spiree 등)  PLJPjg3It2DXTn7wUE7Wx9W9krpQ739TyK
# 9                          슈카월드 경제 썰방송 모음  PLJPjg3It2DXQWxhAz-EFgwk1HqD9QjEhp
# 10                           슈카의 아재토크 풀버전  PLJPjg3It2DXQ62wofZIzsf8Y12OEuopxI
# ...

# %%
#video 정보 추가하기
video_ids = []
video_titles = []
video_dates = []

for playlist_id in playlist_df["playlist_id"]:
    # 해당 playlist_id마다 해당하는 youtube data api 가져오기
    playlist_videos = youtube.playlistItems().list(
        playlistId = playlist_id,
        part = "snippet",
        maxResults = 50
    )
    # playlist_id마다 안에 있는 videos만큼 
    while playlist_videos:
        # .execute()가 뭘 의미하는거지: 해당 api를 실행한다고 생각하자
        playlistitems_list_response = playlist_videos.execute()
        
        for playlist_item in playlistitems_list_response["items"]:
            title = playlist_item["snippet"]["title"]
            video_id = playlist_item["snippet"]["resourceId"]["videoId"]
            video_ids.append(video_id)
            video_titles.append(title)
            
        playlist_video = youtube.playlistItems().list_next(
            playlist_videos, playlistitems_list_response
        )
# Out:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# <ipython-input-15-749b3f66713b> in <module>
#      14     while playlist_videos:
#      15         # .execute()가 뭘 의미하는거지: 해당 api를 실행한다고 생각하자
# ---> 16         playlistitems_list_response = playlist_videos.execute()
#      17
#      18         for playlist_item in playlistitems_list_response["items"]:
#
# C:\ProgramData\Anaconda3\lib\site-packages\googleapiclient\_helpers.py in positional_wrapper(*args, **kwargs)
#     129                 elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     130                     logger.warning(message)
# --> 131             return wrapped(*args, **kwargs)
#     132
#     133         return positional_wrapper
#
# C:\ProgramData\Anaconda3\lib\site-packages\googleapiclient\http.py in execute(self, http, num_retries)
#     935             callback(resp)
# ...

# %%
video_df = pd.DataFrame()
video_df["Title"] = video_titles
video_df["Video Id"] = video_ids

# %%
video_df
